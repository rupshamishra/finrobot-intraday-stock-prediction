# %%
import autogen
import openai
import finrobot

print("All core libraries imported successfully ✅")
# Out:
# All core libraries imported successfully ✅

# %%
# !pip install finnhub-python

# %%
import sys
print(sys.executable)

# %%
C:\Users\KIIT0001\AppData\Local\Programs\Python\Python311\python.exe -m pip install finnhub-python

# %%
import sys
# !{sys.executable} -m pip install finnhub-python

# %%
import sys
print(sys.executable)
import onnxruntime
print("ONNX loaded ✅")
# Out:
# C:\Users\KIIT0001\miniconda3\envs\finrobot\python.exe
# ONNX loaded ✅

# %%
import autogen
from autogen.cache import Cache
from autogen import LLMConfig


from finrobot.utils import get_current_date, register_keys_from_json
from finrobot.data_source.yfinance_utils  import YFinanceUtils
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import autogen
#       2 from autogen.cache import Cache
# ----> 3 from autogen import LLMConfig
#       6 from finrobot.utils import get_current_date, register_keys_from_json
#       7 from finrobot.data_source.yfinance_utils  import YFinanceUtils
#
# ImportError: cannot import name 'LLMConfig' from 'autogen' (C:\Users\KIIT0001\miniconda3\envs\finrobot\lib\site-packages\autogen\__init__.py)
